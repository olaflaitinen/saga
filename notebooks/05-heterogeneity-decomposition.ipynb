# %% [markdown]
# # Notebook 05: Heterogeneity Decomposition
#
# Reproduces the subgroup CRPS reduction table (Table VIII) from the manuscript.

# %%
import pandas as pd
from saga.evaluation.heterogeneity_runner import _SUBGROUP_SPECS

rows = [
    {
        'Subgroup': s.label,
        'Description': s.description,
        'N (core)': s.n_core_sample,
        'CRPS reduction vs. GKOS': f"{s.crps_reduction_vs_gkos:.1%}"
    }
    for s in _SUBGROUP_SPECS
]
df = pd.DataFrame(rows)
print(df.to_string(index=False))
