# %% [markdown]
# # Notebook 02: Lifetime Earnings Aggregation
#
# Demonstrates the Monte Carlo lifetime earnings aggregation procedure (Section III-E)
# and reproduces the Table IV statistics on the synthetic mirror.

# %%
import numpy as np
from saga.evaluation.lifetime_statistics import lifetime_distribution_statistics

rng = np.random.default_rng(20260601)
synthetic_lifetime = rng.lognormal(mean=16.2, sigma=0.7, size=141_074)
stats = lifetime_distribution_statistics(synthetic_lifetime)

print('Lifetime distribution statistics (synthetic, for illustration only):')
for k, v in stats.items():
    print(f'  {k}: {v:.4f}')
